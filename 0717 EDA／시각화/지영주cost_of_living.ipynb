# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
pd.set_option('display.max_columns',None)

# %%
pd.set_option('display.max_rows',None)

# %%
df = pd.read_csv('C:/Users/jyj98/Documents/DAexercise/cost_of_living_2020.csv')

# %%
df.head()
# Out:
#    Rank 2020      Country  Cost of Living Index  Rent Index  \
# 0          1      Bermuda                147.77       85.70
# 1          2  Switzerland                125.69       51.20
# 2          3       Norway                 96.80       32.61
# 3          4      Iceland                 90.19       38.54
# 4          5        Japan                 86.22       26.18
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          117.54           146.63                  152.52
# 1                           89.41           124.93                  118.55
# 2                           65.54            89.55                   96.81
# 3                           65.04            80.91                   97.17
# 4                           56.98            86.84                   48.07
#
#    Local Purchasing Power Index  McMeal($)  Unnamed: 9
# 0                         78.17       0.00         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 135 entries, 0 to 134
# Data columns (total 10 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Rank 2020                       135 non-null    int64
#  1   Country                         135 non-null    object
#  2   Cost of Living Index            135 non-null    float64
#  3   Rent Index                      135 non-null    float64
#  4   Cost of Living Plus Rent Index  135 non-null    float64
#  5   Groceries Index                 135 non-null    float64
#  6   Restaurant Price Index          135 non-null    float64
#  7   Local Purchasing Power Index    135 non-null    float64
#  8   McMeal($)                       135 non-null    float64
#  9   Unnamed: 9                      0 non-null      float64
# dtypes: float64(8), int64(1), object(1)
# memory usage: 10.7+ KB

# %%
len(df)
# Out:
# 135

# %%
#Unnamed 컬럼 삭제
df = df.drop('Unnamed: 9', axis=1)
df.head()
# Out:
#    Rank 2020      Country  Cost of Living Index  Rent Index  \
# 0          1      Bermuda                147.77       85.70
# 1          2  Switzerland                125.69       51.20
# 2          3       Norway                 96.80       32.61
# 3          4      Iceland                 90.19       38.54
# 4          5        Japan                 86.22       26.18
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                          117.54           146.63                  152.52
# 1                           89.41           124.93                  118.55
# 2                           65.54            89.55                   96.81
# 3                           65.04            80.91                   97.17
# 4                           56.98            86.84                   48.07
#
#    Local Purchasing Power Index  McMeal($)
# 0                         78.17       0.00
# 1                        114.83      15.36
# ...

# %%
df.Country
# Out:
# 0                          Bermuda
# 1                      Switzerland
# 2                           Norway
# 3                          Iceland
# 4                            Japan
# 5                          Denmark
# 6                       Luxembourg
# 7                          Bahamas
# 8                           Israel
# 9                        Singapore
# 10                        Barbados
# 11                         Ireland
# 12                       Hong Kong
# 13                          France
# 14                     South Korea
# 15                       Australia
# 16                     Netherlands
# 17                      Seychelles
# 18                         Belgium
# 19                         Finland
# 20                   United States
# 21                          Sweden
# 22                     New Zealand
# 23                         Austria
# 24                           Macao
# 25                     Puerto Rico
# 26                           Malta
# ...

# %%
asia_idx = [4, 9, 12, 14, 24, 35, 77, 89]

# %%
df_a = df.iloc[asia_idx,:]
df_a.index = np.arange(0, len(df_a))
df_a
# Out:
#    Rank 2020      Country  Cost of Living Index  Rent Index  \
# 0          5        Japan                 86.22       26.18
# 1         10    Singapore                 81.13       61.27
# 2         13    Hong Kong                 77.90       75.26
# 3         15  South Korea                 75.93       21.91
# 4         25        Macao                 70.18       42.47
# 5         36       Taiwan                 61.95       16.87
# 6         78        China                 39.51       15.20
# 7         90      Vietnam                 38.12       13.48
#
#    Cost of Living Plus Rent Index  Groceries Index  Restaurant Price Index  \
# 0                           56.98            86.84                   48.07
# 1                           71.46            69.20                   58.00
# 2                           76.62            77.47                   54.70
# 3                           49.63            91.35                   40.47
# ...

# %%
df_a.index = df_a.Country
df_a
# Out:
#              Rank 2020      Country  Cost of Living Index  Rent Index  \
# Country
# Japan                5        Japan                 86.22       26.18
# Singapore           10    Singapore                 81.13       61.27
# Hong Kong           13    Hong Kong                 77.90       75.26
# South Korea         15  South Korea                 75.93       21.91
# Macao               25        Macao                 70.18       42.47
# Taiwan              36       Taiwan                 61.95       16.87
# China               78        China                 39.51       15.20
# Vietnam             90      Vietnam                 38.12       13.48
#
#              Cost of Living Plus Rent Index  Groceries Index  \
# Country
# Japan                                 56.98            86.84
# Singapore                             71.46            69.20
# Hong Kong                             76.62            77.47
# South Korea                           49.63            91.35
# ...

# %%
df_a.describe()
# Out:
#        Rank 2020  Cost of Living Index  Rent Index  \
# count   8.000000              8.000000    8.000000
# mean   34.000000             66.367500   34.080000
# std    32.460966             18.476971   23.277819
# min     5.000000             38.120000   13.480000
# 25%    12.250000             56.340000   16.452500
# 50%    20.000000             73.055000   24.045000
# 75%    46.500000             78.707500   47.170000
# max    90.000000             86.220000   75.260000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                        8.000000         8.000000
# mean                        50.646250        68.202500
# std                         18.625296        19.519878
# min                         26.120000        37.650000
# 25%                         36.917500        60.802500
# 50%                         53.160000        71.850000
# 75%                         60.600000        79.812500
# max                         76.620000        91.350000
#
# ...

# %%
df.describe().iloc[1,1:]
# Out:
#         Rank 2020  Cost of Living Index  Rent Index  \
# count  135.000000            135.000000  135.000000
# mean    68.000000             50.349185   18.104519
# std     39.115214             20.464727   13.576029
# min      1.000000             21.000000    3.990000
# 25%     34.500000             36.220000    9.365000
# 50%     68.000000             44.960000   13.480000
# 75%    101.500000             63.620000   23.390000
# max    135.000000            147.770000   85.700000
#
#        Cost of Living Plus Rent Index  Groceries Index  \
# count                      135.000000       135.000000
# mean                        34.647185        44.881852
# std                         16.426949        20.167978
# min                         12.860000        18.210000
# 25%                         23.110000        30.265000
# 50%                         29.960000        38.630000
# 75%                         44.270000        55.495000
# ...

# %%
#line plot

color=['black','lime','b','magenta','r','coral','deepskyblue','cyan']
plt.figure(figsize=(30,20))
for i in range(0,8):
    plt.plot(df_a.columns[2:], df_a.iloc[i,2:] , color=color[i], marker='o')
plt.legend(df_a.index, fontsize=20)

# %%
#line plot

color=['black','lime','b','magenta','r','coral','deepskyblue','cyan']
plt.figure(figsize=(30,20))
for i in range(0,8):
    plt.plot(df_a.columns[2:8], df_a.iloc[i,2:8] , color=color[i], marker='o')

plt.legend(df_a.index, fontsize=20)

# %%
#홍콩과 싱가포르/중국과 베트남

# %%
df_a.sort_values(by='McMeal($)',ascending=False)
# Out:
#              Rank 2020      Country  Cost of Living Index  Rent Index  \
# Country
# Japan                5        Japan                 86.22       26.18
# Singapore           10    Singapore                 81.13       61.27
# South Korea         15  South Korea                 75.93       21.91
# China               78        China                 39.51       15.20
# Hong Kong           13    Hong Kong                 77.90       75.26
# Taiwan              36       Taiwan                 61.95       16.87
# Vietnam             90      Vietnam                 38.12       13.48
# Macao               25        Macao                 70.18       42.47
#
#              Cost of Living Plus Rent Index  Groceries Index  \
# Country
# Japan                                 56.98            86.84
# Singapore                             71.46            69.20
# South Korea                           49.63            91.35
# China                                 27.67            41.31
# ...

# %%
asia_mean = df_a.describe().iloc[1,1:]
asia_mean.name = 'asia'
asia_mean
# Out:
# Cost of Living Index              66.36750
# Rent Index                        34.08000
# Cost of Living Plus Rent Index    50.64625
# Groceries Index                   68.20250
# Restaurant Price Index            40.14000
# Local Purchasing Power Index      66.49625
# McMeal($)                          4.73500
# Name: asia, dtype: float64

# %%
world_mean = df.describe().iloc[1,1:]
world_mean.name = 'world'
world_mean
# Out:
# Cost of Living Index              50.349185
# Rent Index                        18.104519
# Cost of Living Plus Rent Index    34.647185
# Groceries Index                   44.881852
# Restaurant Price Index            41.080889
# Local Purchasing Power Index      47.134593
# McMeal($)                          4.924296
# Name: world, dtype: float64

# %%
compare = pd.concat([asia_mean, world_mean], axis=1)
compare
# Out:
#                                     asia      world
# Cost of Living Index            66.36750  50.349185
# Rent Index                      34.08000  18.104519
# Cost of Living Plus Rent Index  50.64625  34.647185
# Groceries Index                 68.20250  44.881852
# Restaurant Price Index          40.14000  41.080889
# Local Purchasing Power Index    66.49625  47.134593
# McMeal($)                        4.73500   4.924296

# %%
plt.bar([0,1], compare.iloc[0,:])
plt.title(compare.index[0])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c438e2be0>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[1,:])
plt.title(compare.index[1])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c443cdc70>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[2,:])
plt.title(compare.index[2])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c423d2e50>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[3,:])
plt.title(compare.index[3])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c444e0d30>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[4,:])
plt.title(compare.index[4])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c435f7460>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[5,:])
plt.title(compare.index[5])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c44584d60>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
plt.bar([0,1], compare.iloc[6,:])
plt.title(compare.index[6])
plt.xticks([0,1], compare.columns, fontsize=15)
# Out:
# ([<matplotlib.axis.XTick at 0x28c445d4d30>,
# ...
#  [Text(0, 0, 'asia'), Text(1, 0, 'world')])

# %%
#line plot

color=['black','lime','b','magenta','r','deepskyblue','cyan']
plt.figure(figsize=(20, 15))
for i in range(0,7):
    plt.plot(compare.columns, compare.iloc[i,:] , color=color[i], marker='o')

plt.legend(compare.index, fontsize=20)

# %%
#레스토랑 가격, 맥밀
